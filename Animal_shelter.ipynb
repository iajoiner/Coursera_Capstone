# %% [markdown]
# # Location for a new animal shelter in Toronto

# %% [markdown]
# **Ying Zhou**

# %% [markdown]
# **Time for the usual imports**

# %%
import pandas as pd
import numpy as np
import requests
import folium

# %% [markdown]
# Let's put the url together.

# %% [markdown]
# The CAT_LIST includes the following categories: Animal shelters, pet cafes, pet service, pet store and veterinarians. All the categories are available here: https://developer.foursquare.com/docs/resources/categories The reason why I chose radius = 5000 is that when it is much larger the amount of results actually decrease.

# %%
CLIENT_ID = '35JVTJQ3DWXUWRZWIVRBAPEDD515TCLODKSVFL1TMKE0VOME' # your Foursquare ID
CLIENT_SECRET = 'UHOTU4NXUEBTO15T4BA3XN0032VU1TZ1OGSMXDRMCO5NGMMK' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version
LATITUDE = 43.70011
LONGITUDE = -79.4163
CAT_LIST = '56aa371be4b08b9a8d573508,5032897c91d4c4b30a586d69,4bf58dd8d48988d100951735,4e52d2d203646f7c19daa8ae,4d954af4a243a5684765b473'
LIMIT = 300
radius = 10000
url = 'https://api.foursquare.com/v2/venues/search?&client_id={}&client_secret={}&v={}&intent=checkin&ll={},{}&categoryId={}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    LATITUDE, 
    LONGITUDE,
    CAT_LIST,
    radius, 
    LIMIT)

# %%
results = requests.get(url).json()

# %%
size = len(results['response']['venues'])
size
# Out:
# 50

# %% [markdown]
# OK so we have 50 locations! :-)

# %%
res_arr = results['response']['venues']
#df = pd.DataFrame(columns = ['name', 'address','latitude','longitude', 'category', 'zipcode'])
data_list = []
for res in res_arr:
    name = res['name']
    address = ', '.join(res['location']['formattedAddress'])
    latitude = res['location']['lat']
    longitude = res['location']['lng']
    category = res['categories'][0]['name']
    zipcode = res['location'].get('postalCode','N/A').upper()
    zip3 = zipcode[0:3]
    data_list = data_list + [[name, address, latitude, longitude, category, zipcode]]
df = pd.DataFrame(data_list,columns = ['name', 'address','latitude','longitude', 'category', 'zipcode'])
df
# Out:
#                                           name  \
# 0   Central Toronto Veterinary Referral Clinic
# 1                                     PetSmart
# 2                                     PetSmart
# 3                                     Pet Valu
# 4                             Global Pet Foods
# 5                                     Pet Valu
# 6                              Dogfather & Co.
# 7                             Global Pet Foods
# 8                             Global Pet Foods
# 9                             Global Pet Foods
# 10                                   Urban Dog
# 11                               Big Paws inc.
# 12                                    Pet Valu
# 13                                    Pet Valu
# 14                      Pet Valu @Parkway mall
# 15                             Ren's Pet Depot
# 16                                    PetSmart
# 17                                    Pet Valu
# 18                                     Pet Uno
# 19                                    Pet Valu
# 20                            Ren's Pets Depot
# 21                              Kennel Cafe #2
# 22                                    Pet Valu
# 23            Cosmopawlitan Pet Boutique + Spa
# 24                                    Pet Valu
# 25                                    PetSmart
# 26                                    Pet Valu
# 27                                 Pet Cuisine
# 28                                     PawsWay
# 29                            The Cat Hospital
# 30                          Menagerie Pet Shop
# 31                Roncesvalles Animal Hospital
# 32                                The Dog Bowl
# 33             VEC Veterinary Emergency Clinic
# 34                          That Dog Next Door
# 35         Toronto Centre for Canine Education
# 36              Davenport Road Animal Hospital
# 37                    Downtown Animal Hospital
# 38                    Links Road Animal Clinic
# 39                  Don Valley Animal Hospital
# 40       Toronto Veterinary Emergency Hospital
# 41                                 Tailwaggers
# 42                 Dundas West Animal Hospital
# 43                     Spadina Animal Hospital
# 44                  Willowdale Animal Hospital
# 45                  Royal York Animal Hospital
# 46                Front Street Animal Hospital
# 47                      Toronto Humane Society
# 48                 Downtown Toronto Cat Clinic
# 49               Dundas Euclid Animal Hospital
#
#                                               address   latitude  longitude  \
# 0     1051 Eglinton Ave W, Toronto ON M6C 2C9, Canada  43.699336 -79.433081
# 1   835 Eglinton Ave E (at Laird Dr.), East York O...  43.712682 -79.362636
# 2   75 Gunns Road, Unit 103, Toronto ON M6N 0A3, C...  43.675062 -79.471696
# 3   339 College St (at Augusta Ave), Toronto ON M5...  43.657322 -79.402946
# 4               133 Danforth Ave., Toronto ON, Canada  43.676913 -79.355225
# 5   1660 Bloor St W (at Indian Rd), Toronto ON M6P...  43.655366 -79.457232
# 6   1007 Yonge Street (Crescent Rd.), Toronto ON M...  43.677205 -79.389451
# 7   2019 Yonge St (Manor Rd E), Toronto ON M4S 2A2...  43.701266 -79.397115
# 8                          Dupont, Toronto ON, Canada  43.675580 -79.403386
# 9        1947 Avenue Rd. (Wilson), Toronto ON, Canada  43.734015 -79.419371
# 10       37 Parliament St, Toronto ON M5A 2Y2, Canada  43.649493 -79.361617
# 11                        1847 Davenport Road, Canada  43.670456 -79.453072
# 12      3003 Danforth Ave, Toronto ON M4C 1M9, Canada  43.700651 -79.297165
# 13  184 Front St E (at Princess St), Toronto ON M5...  43.650618 -79.366880
# 14                            85 Ellesmere Rd, Canada  43.757930 -79.313445
# 15                         Toronto ON M1L 4V9, Canada  43.725628 -79.291600
# 16  Empress Walk (Empress Avenue), Toronto ON M2N ...  43.769139 -79.412522
# 17  2578 Yonge St (at Albertus Ave), Toronto ON M4...  43.714126 -79.399975
# 18                 675 College St, Toronto ON, Canada  43.655130 -79.417211
# 19  240 Carlton St (at Parliament St), Toronto ON ...  43.664205 -79.368460
# 20                 Wilson Ave, Toronto ON M3K, Canada  43.734013 -79.451760
# 21  2363 Lakeshore Road West (Albert Avenue), Toro...  43.616111 -79.488197
# 22  4242 Dundas St W (at Royal York Rd), Toronto O...  43.659612 -79.513945
# 23  478 Queens Quay West (Spadina), Toronto ON M5V...  43.637365 -79.393819
# 24  1245 Dupont St (at Dufferin St), Toronto ON M6...  43.667096 -79.441757
# 25  700 Lawrence Ave West, Unit M3B (Allen Rd), To...  43.716806 -79.447298
# 26  748 Sheppard Ave E (at Burbank Dr), Toronto ON...  43.769562 -79.375625
# 27  127 Front St E (at George Street), Toronto ON ...  43.649970 -79.369924
# 28  245 Queens Quay W (North Building), Toronto ON...  43.638599 -79.384992
# 29                                 Toronto ON, Canada  43.781657 -79.406792
# 30  549 Parliament St. (btwn Carlton & Wellesley),...  43.666445 -79.368774
# 31  18 Roncesvalles Ave (Queen Street), Toronto ON...  43.639659 -79.446290
# 32  984 Dundas St. W (at Beatrice St.), Toronto ON...  43.650483 -79.415143
# 33  117-920 Yonge St (Entrance on McMurrich St), T...  43.673978 -79.389731
# 34        1230 Bloor St W, Toronto ON M6H 1N3, Canada  43.659052 -79.439340
# 35              388 Carlaw Avenue, Toronto ON, Canada  43.666447 -79.342220
# 36      303 Davenport Rd., Toronto ON M5R 1K5, Canada  43.674605 -79.400694
# 37  579 Church St (Isabella), Toronto ON M4Y 2E4, ...  43.667939 -79.381714
# 38  41 The Links Rd (btw Tournament Dr & Lord Seat...  43.751109 -79.401096
# 39  895 Lawrence Ave. E (at The Donway W), Toronto...  43.735885 -79.347051
# 40          21 Rolark Dr., Toronto ON M1R 3B1, Canada  43.764636 -79.292965
# 41  3073 Dundas Street West, (High Park & Dundas),...  43.665376 -79.471755
# 42     2160 Dundas St. W., Toronto ON M6R 1X3, Canada  43.653235 -79.450370
# 43  125 Spadina Ave (Adelaide), Toronto ON M5V 2K8...  43.647223 -79.395658
# 44  256 Sheppard Ave W, North York ON M2N 1N3, Canada  43.758899 -79.423170
# 45       4222 Dundas St W, Toronto ON M8X 1Y6, Canada  43.660129 -79.512446
# 46  548 Front Street West (Bathurst), Toronto ON, ...  43.640932 -79.399037
# 47  11 River St. (Queen St. E), Toronto ON M5A 4C2...  43.657698 -79.356583
# 48  739 Bloor Street West, Toronto ON M6G 1L6, Canada  43.663301 -79.419065
# 49  840 Dundas St. W. (Euclid), Toronto ON M6J 1V5...  43.651518 -79.409984
#
#           category  zipcode
# 0     Veterinarian  M6C 2C9
# 1        Pet Store  M4G 4G9
# 2        Pet Store  M6N 0A3
# 3        Pet Store  M5T 1S2
# 4        Pet Store      N/A
# 5        Pet Store  M6P 1A8
# 6        Pet Store  M4W 2K9
# 7        Pet Store  M4S 2A2
# 8        Pet Store      N/A
# 9        Pet Store      N/A
# 10       Pet Store  M5A 2Y2
# 11       Pet Store      N/A
# 12       Pet Store  M4C 1M9
# 13       Pet Store  M5A 4N3
# 14       Pet Store      N/A
# 15       Pet Store  M1L 4V9
# 16       Pet Store  M2N 5N9
# 17       Pet Store  M4P 2J3
# 18       Pet Store      N/A
# 19       Pet Store  M5A 2L1
# 20       Pet Store      M3K
# 21       Pet Store      N/A
# 22       Pet Store  M8X 1Y6
# 23       Pet Store  M5V 2Y3
# 24       Pet Store  M6H 2A6
# 25       Pet Store  M6A 3B4
# 26       Pet Store  M2K 1C3
# 27       Pet Store  M5A 1E3
# 28     Event Space  M5J 2K9
# 29    Veterinarian      N/A
# 30       Pet Store  M4X 1P7
# 31    Veterinarian  M6R 2K3
# 32       Pet Store  M6J 1W6
# 33    Veterinarian  M4W 3C7
# 34     Pet Service  M6H 1N3
# 35     Pet Service      N/A
# 36    Veterinarian  M5R 1K5
# 37    Veterinarian  M4Y 2E4
# 38    Veterinarian  M2P 1T7
# 39    Veterinarian      N/A
# 40    Veterinarian  M1R 3B1
# 41     Pet Service  M6P 1Z5
# 42    Veterinarian  M6R 1X3
# 43    Veterinarian  M5V 2K8
# 44    Veterinarian  M2N 1N3
# 45    Veterinarian  M8X 1Y6
# 46    Veterinarian      N/A
# 47  Animal Shelter  M5A 4C2
# 48    Veterinarian  M6G 1L6
# 49        Hospital  M6J 1V5

# %% [markdown]
# Now let's clean up the data. Row 49 is actually an animal hospital. So let's fix that. All other categorizations are mostly accurate.

# %%
df.loc[49, 'category'] = 'Pet Store'
df
# Out:
#                                           name  \
# 0   Central Toronto Veterinary Referral Clinic
# 1                                     PetSmart
# 2                                     PetSmart
# 3                                     Pet Valu
# 4                             Global Pet Foods
# 5                                     Pet Valu
# 6                              Dogfather & Co.
# 7                             Global Pet Foods
# 8                             Global Pet Foods
# 9                             Global Pet Foods
# 10                                   Urban Dog
# 11                               Big Paws inc.
# 12                                    Pet Valu
# 13                                    Pet Valu
# 14                      Pet Valu @Parkway mall
# 15                             Ren's Pet Depot
# 16                                    PetSmart
# 17                                    Pet Valu
# 18                                     Pet Uno
# 19                                    Pet Valu
# 20                            Ren's Pets Depot
# 21                              Kennel Cafe #2
# 22                                    Pet Valu
# 23            Cosmopawlitan Pet Boutique + Spa
# 24                                    Pet Valu
# 25                                    PetSmart
# 26                                    Pet Valu
# 27                                 Pet Cuisine
# 28                                     PawsWay
# 29                            The Cat Hospital
# 30                          Menagerie Pet Shop
# 31                Roncesvalles Animal Hospital
# 32                                The Dog Bowl
# 33             VEC Veterinary Emergency Clinic
# 34                          That Dog Next Door
# 35         Toronto Centre for Canine Education
# 36              Davenport Road Animal Hospital
# 37                    Downtown Animal Hospital
# 38                    Links Road Animal Clinic
# 39                  Don Valley Animal Hospital
# 40       Toronto Veterinary Emergency Hospital
# 41                                 Tailwaggers
# 42                 Dundas West Animal Hospital
# 43                     Spadina Animal Hospital
# 44                  Willowdale Animal Hospital
# 45                  Royal York Animal Hospital
# 46                Front Street Animal Hospital
# 47                      Toronto Humane Society
# 48                 Downtown Toronto Cat Clinic
# 49               Dundas Euclid Animal Hospital
#
#                                               address   latitude  longitude  \
# 0     1051 Eglinton Ave W, Toronto ON M6C 2C9, Canada  43.699336 -79.433081
# 1   835 Eglinton Ave E (at Laird Dr.), East York O...  43.712682 -79.362636
# 2   75 Gunns Road, Unit 103, Toronto ON M6N 0A3, C...  43.675062 -79.471696
# 3   339 College St (at Augusta Ave), Toronto ON M5...  43.657322 -79.402946
# 4               133 Danforth Ave., Toronto ON, Canada  43.676913 -79.355225
# 5   1660 Bloor St W (at Indian Rd), Toronto ON M6P...  43.655366 -79.457232
# 6   1007 Yonge Street (Crescent Rd.), Toronto ON M...  43.677205 -79.389451
# 7   2019 Yonge St (Manor Rd E), Toronto ON M4S 2A2...  43.701266 -79.397115
# 8                          Dupont, Toronto ON, Canada  43.675580 -79.403386
# 9        1947 Avenue Rd. (Wilson), Toronto ON, Canada  43.734015 -79.419371
# 10       37 Parliament St, Toronto ON M5A 2Y2, Canada  43.649493 -79.361617
# 11                        1847 Davenport Road, Canada  43.670456 -79.453072
# 12      3003 Danforth Ave, Toronto ON M4C 1M9, Canada  43.700651 -79.297165
# 13  184 Front St E (at Princess St), Toronto ON M5...  43.650618 -79.366880
# 14                            85 Ellesmere Rd, Canada  43.757930 -79.313445
# 15                         Toronto ON M1L 4V9, Canada  43.725628 -79.291600
# 16  Empress Walk (Empress Avenue), Toronto ON M2N ...  43.769139 -79.412522
# 17  2578 Yonge St (at Albertus Ave), Toronto ON M4...  43.714126 -79.399975
# 18                 675 College St, Toronto ON, Canada  43.655130 -79.417211
# 19  240 Carlton St (at Parliament St), Toronto ON ...  43.664205 -79.368460
# 20                 Wilson Ave, Toronto ON M3K, Canada  43.734013 -79.451760
# 21  2363 Lakeshore Road West (Albert Avenue), Toro...  43.616111 -79.488197
# 22  4242 Dundas St W (at Royal York Rd), Toronto O...  43.659612 -79.513945
# 23  478 Queens Quay West (Spadina), Toronto ON M5V...  43.637365 -79.393819
# 24  1245 Dupont St (at Dufferin St), Toronto ON M6...  43.667096 -79.441757
# 25  700 Lawrence Ave West, Unit M3B (Allen Rd), To...  43.716806 -79.447298
# 26  748 Sheppard Ave E (at Burbank Dr), Toronto ON...  43.769562 -79.375625
# 27  127 Front St E (at George Street), Toronto ON ...  43.649970 -79.369924
# 28  245 Queens Quay W (North Building), Toronto ON...  43.638599 -79.384992
# 29                                 Toronto ON, Canada  43.781657 -79.406792
# 30  549 Parliament St. (btwn Carlton & Wellesley),...  43.666445 -79.368774
# 31  18 Roncesvalles Ave (Queen Street), Toronto ON...  43.639659 -79.446290
# 32  984 Dundas St. W (at Beatrice St.), Toronto ON...  43.650483 -79.415143
# 33  117-920 Yonge St (Entrance on McMurrich St), T...  43.673978 -79.389731
# 34        1230 Bloor St W, Toronto ON M6H 1N3, Canada  43.659052 -79.439340
# 35              388 Carlaw Avenue, Toronto ON, Canada  43.666447 -79.342220
# 36      303 Davenport Rd., Toronto ON M5R 1K5, Canada  43.674605 -79.400694
# 37  579 Church St (Isabella), Toronto ON M4Y 2E4, ...  43.667939 -79.381714
# 38  41 The Links Rd (btw Tournament Dr & Lord Seat...  43.751109 -79.401096
# 39  895 Lawrence Ave. E (at The Donway W), Toronto...  43.735885 -79.347051
# 40          21 Rolark Dr., Toronto ON M1R 3B1, Canada  43.764636 -79.292965
# 41  3073 Dundas Street West, (High Park & Dundas),...  43.665376 -79.471755
# 42     2160 Dundas St. W., Toronto ON M6R 1X3, Canada  43.653235 -79.450370
# 43  125 Spadina Ave (Adelaide), Toronto ON M5V 2K8...  43.647223 -79.395658
# 44  256 Sheppard Ave W, North York ON M2N 1N3, Canada  43.758899 -79.423170
# 45       4222 Dundas St W, Toronto ON M8X 1Y6, Canada  43.660129 -79.512446
# 46  548 Front Street West (Bathurst), Toronto ON, ...  43.640932 -79.399037
# 47  11 River St. (Queen St. E), Toronto ON M5A 4C2...  43.657698 -79.356583
# 48  739 Bloor Street West, Toronto ON M6G 1L6, Canada  43.663301 -79.419065
# 49  840 Dundas St. W. (Euclid), Toronto ON M6J 1V5...  43.651518 -79.409984
#
#           category  zipcode
# 0     Veterinarian  M6C 2C9
# 1        Pet Store  M4G 4G9
# 2        Pet Store  M6N 0A3
# 3        Pet Store  M5T 1S2
# 4        Pet Store      N/A
# 5        Pet Store  M6P 1A8
# 6        Pet Store  M4W 2K9
# 7        Pet Store  M4S 2A2
# 8        Pet Store      N/A
# 9        Pet Store      N/A
# 10       Pet Store  M5A 2Y2
# 11       Pet Store      N/A
# 12       Pet Store  M4C 1M9
# 13       Pet Store  M5A 4N3
# 14       Pet Store      N/A
# 15       Pet Store  M1L 4V9
# 16       Pet Store  M2N 5N9
# 17       Pet Store  M4P 2J3
# 18       Pet Store      N/A
# 19       Pet Store  M5A 2L1
# 20       Pet Store      M3K
# 21       Pet Store      N/A
# 22       Pet Store  M8X 1Y6
# 23       Pet Store  M5V 2Y3
# 24       Pet Store  M6H 2A6
# 25       Pet Store  M6A 3B4
# 26       Pet Store  M2K 1C3
# 27       Pet Store  M5A 1E3
# 28     Event Space  M5J 2K9
# 29    Veterinarian      N/A
# 30       Pet Store  M4X 1P7
# 31    Veterinarian  M6R 2K3
# 32       Pet Store  M6J 1W6
# 33    Veterinarian  M4W 3C7
# 34     Pet Service  M6H 1N3
# 35     Pet Service      N/A
# 36    Veterinarian  M5R 1K5
# 37    Veterinarian  M4Y 2E4
# 38    Veterinarian  M2P 1T7
# 39    Veterinarian      N/A
# 40    Veterinarian  M1R 3B1
# 41     Pet Service  M6P 1Z5
# 42    Veterinarian  M6R 1X3
# 43    Veterinarian  M5V 2K8
# 44    Veterinarian  M2N 1N3
# 45    Veterinarian  M8X 1Y6
# 46    Veterinarian      N/A
# 47  Animal Shelter  M5A 4C2
# 48    Veterinarian  M6G 1L6
# 49       Pet Store  M6J 1V5

# %% [markdown]
# We also have several locations with completely ridiculous addresses or missing postal codes. That's fine since we only need their latitude and longitude anyway. Now it is time for a relabelling.

# %% [markdown]
# Now let's plot the 50 pet-related locations on a Folium map.

# %%
toronto_map = folium.Map(location=[LATITUDE, LONGITUDE], zoom_start=11)
for lat, lng, category, name in zip(df.latitude, df.longitude, df.category, df.name):
    folium.vector_layers.CircleMarker(
        [lat, lng],
        radius=5, # define how big you want the circle markers to be
        color='yellow',
        fill=True,
        popup=name + ' ' + category,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(toronto_map)

# show map
toronto_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# It seems that pets are indeed popular in Toronto! Using different approaches we can actually get different results and changing the limit does not seem to improve the situation. Hence we are going to define Pet Score (PS) of a neighborhood using the distance between the center of the neighborhood and the 5 nearest pet locations.

# %%
import scipy as sp

# %% [markdown]
# Now we need to import the old neighborhood information from our .csv file. Note that M5W and M7Y aren't exactly neighborhoods. However they are still locations in a borough which is why they are still useful.

# %%
df_loc = pd.read_csv('/Users/CatLover/Documents/Python_Gamma/Jupiter Notebookz/neighborhoods_with_location.csv', index_col = 0)
df_loc.head()
# Out:
#   PostalCode           Borough                      Neighborhood   Latitude  \
# 0        M3A        North York                         Parkwoods  43.753259
# 1        M4A        North York                  Victoria Village  43.725882
# 2        M5A  Downtown Toronto         Harbourfront, Regent Park  43.654260
# 3        M6A        North York  Lawrence Heights, Lawrence Manor  43.718518
# 4        M7A      Queen's Park                      Queen's Park  43.662301
#
#    Longitude
# 0 -79.329656
# 1 -79.315572
# 2 -79.360636
# 3 -79.464763
# 4 -79.389494

# %% [markdown]
# Now let's calculate the PS. Since we have no information on whether animal shelters should be in rich or middle class neighborhoods nor can we really estimate the actual population that passes through an area we decide that PS should solely depend on how many existing pet-related venues exist near a neighborhood. Let's use 1 km as the radius because we assume that it is easy for many customers to walk for a 1km while visiting multiple pet-related venues. The actual distance between the center of a neighborhood and a pet-related venue is not used because a neighborhood has size and the center does not represent the entire neighborhood.

# %%
def get_pet_score(lat, lng, amount = 1000):
    url = 'https://api.foursquare.com/v2/venues/search?&client_id={}&client_secret={}&intent=checkin&v={}&ll={},{}&categoryId={}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    lat, 
    lng,
    CAT_LIST,
    amount, 
    LIMIT)
    results = requests.get(url).json()
    res_array = results['response']['venues']
    count = len(res_array) + 1 #Because this new animal shelter also counts!
    #for res in res_array:
        #print(res['name'])
    return count

# %%
ps = [None] * df_loc.shape[0]
for index, row in df_loc.iterrows():
    print(row.PostalCode)
    #print(index)
    ps[index] = get_pet_score(row.Latitude, row.Longitude)
print(ps)

#df_loc.head()
# Out:
# M3A
# M4A
# M5A
# M6A
# M7A
# M9A
# M1B
# M3B
# M4B
# M5B
# M6B
# M9B
# M1C
# M3C
# M4C
# M5C
# M6C
# M9C
# M1E
# M4E
# M5E
# M6E
# M1G
# M4G
# M5G
# M6G
# M1H
# M2H
# M3H
# M4H
# M5H
# M6H
# M1J
# M2J
# M3J
# M4J
# M5J
# M6J
# M1K
# M2K
# M3K
# M4K
# M5K
# M6K
# M1L
# M2L
# M3L
# M4L
# M5L
# M6L
# M9L
# M1M
# M2M
# M3M
# M4M
# M5M
# M6M
# M9M
# M1N
# M2N
# M3N
# M4N
# M5N
# M6N
# M9N
# M1P
# M2P
# M4P
# M5P
# M6P
# M9P
# M1R
# M2R
# M4R
# M5R
# M6R
# M7R
# M9R
# M1S
# M4S
# M5S
# M6S
# M1T
# M4T
# M5T
# M1V
# M4V
# M5V
# M8V
# M9V
# M1W
# M4W
# M5W
# M8W
# M9W
# M1X
# M4X
# M5X
# M8X
# M4Y
# M7Y
# M8Y
# M8Z
# [3, 5, 24, 4, 15, 1, 3, 6, 6, 23, 3, 2, 3, 1, 5, 19, 7, 4, 2, 18, 12, 3, 2, 9, 17, 17, 7, 2, 6, 9, 19, 13, 2, 1, 2, 7, 9, 23, 4, 3, 2, 10, 19, 10, 1, 1, 1, 12, 22, 2, 3, 4, 3, 2, 12, 8, 1, 1, 1, 12, 2, 2, 9, 5, 3, 4, 4, 16, 8, 16, 4, 3, 2, 9, 18, 15, 4, 2, 6, 19, 14, 10, 3, 4, 22, 2, 10, 7, 4, 1, 1, 7, 18, 2, 1, 1, 13, 18, 8, 20, 11, 3, 8]

# %%
#print(len(ps))
df_loc.insert(loc = 5, column = 'PetScore', value = ps)
df_loc
# Out:
#     PostalCode           Borough  \
# 0          M3A        North York
# 1          M4A        North York
# 2          M5A  Downtown Toronto
# 3          M6A        North York
# 4          M7A      Queen's Park
# 5          M9A         Etobicoke
# 6          M1B       Scarborough
# 7          M3B        North York
# 8          M4B         East York
# 9          M5B  Downtown Toronto
# 10         M6B        North York
# 11         M9B         Etobicoke
# 12         M1C       Scarborough
# 13         M3C        North York
# 14         M4C         East York
# 15         M5C  Downtown Toronto
# 16         M6C              York
# 17         M9C         Etobicoke
# 18         M1E       Scarborough
# 19         M4E      East Toronto
# 20         M5E  Downtown Toronto
# 21         M6E              York
# 22         M1G       Scarborough
# 23         M4G         East York
# 24         M5G  Downtown Toronto
# 25         M6G  Downtown Toronto
# 26         M1H       Scarborough
# 27         M2H        North York
# 28         M3H        North York
# 29         M4H         East York
# ..         ...               ...
# 73         M4R   Central Toronto
# 74         M5R   Central Toronto
# 75         M6R      West Toronto
# 76         M7R       Mississauga
# 77         M9R         Etobicoke
# 78         M1S       Scarborough
# 79         M4S   Central Toronto
# 80         M5S  Downtown Toronto
# 81         M6S      West Toronto
# 82         M1T       Scarborough
# 83         M4T   Central Toronto
# 84         M5T  Downtown Toronto
# 85         M1V       Scarborough
# 86         M4V   Central Toronto
# 87         M5V  Downtown Toronto
# 88         M8V         Etobicoke
# 89         M9V         Etobicoke
# 90         M1W       Scarborough
# 91         M4W  Downtown Toronto
# 92         M5W  Downtown Toronto
# 93         M8W         Etobicoke
# 94         M9W         Etobicoke
# 95         M1X       Scarborough
# 96         M4X  Downtown Toronto
# 97         M5X  Downtown Toronto
# 98         M8X         Etobicoke
# 99         M4Y  Downtown Toronto
# 100        M7Y      East Toronto
# 101        M8Y         Etobicoke
# 102        M8Z         Etobicoke
#
#                                           Neighborhood   Latitude  Longitude  \
# 0                                            Parkwoods  43.753259 -79.329656
# 1                                     Victoria Village  43.725882 -79.315572
# 2                            Harbourfront, Regent Park  43.654260 -79.360636
# 3                     Lawrence Heights, Lawrence Manor  43.718518 -79.464763
# 4                                         Queen's Park  43.662301 -79.389494
# 5                                     Islington Avenue  43.667856 -79.532242
# 6                                       Rouge, Malvern  43.806686 -79.194353
# 7                                      Don Mills North  43.745906 -79.352188
# 8                      Woodbine Gardens, Parkview Hill  43.706397 -79.309937
# 9                             Ryerson, Garden District  43.657162 -79.378937
# 10                                           Glencairn  43.709577 -79.445073
# 11   Cloverdale, Islington, Martin Grove, Princess ...  43.650943 -79.554724
# 12              Highland Creek, Rouge Hill, Port Union  43.784535 -79.160497
# 13                    Flemingdon Park, Don Mills South  43.725900 -79.340923
# 14                                    Woodbine Heights  43.695344 -79.318389
# 15                                      St. James Town  43.651494 -79.375418
# 16                                  Humewood-Cedarvale  43.693781 -79.428191
# 17   Bloordale Gardens, Eringate, Markland Wood, Ol...  43.643515 -79.577201
# 18                   Guildwood, Morningside, West Hill  43.763573 -79.188711
# 19                                         The Beaches  43.676357 -79.293031
# 20                                         Berczy Park  43.644771 -79.373306
# 21                                 Caledonia-Fairbanks  43.689026 -79.453512
# 22                                              Woburn  43.770992 -79.216917
# 23                                             Leaside  43.709060 -79.363452
# 24                                  Central Bay Street  43.657952 -79.387383
# 25                                            Christie  43.669542 -79.422564
# 26                                           Cedarbrae  43.773136 -79.239476
# 27                                   Hillcrest Village  43.803762 -79.363452
# 28     Bathurst Manor, Downsview North, Wilson Heights  43.754328 -79.442259
# 29                                    Thorncliffe Park  43.705369 -79.349372
# ..                                                 ...        ...        ...
# 73                                  North Toronto West  43.715383 -79.405678
# 74                 The Annex, North Midtown, Yorkville  43.672710 -79.405678
# 75                              Parkdale, Roncesvalles  43.648960 -79.456325
# 76               Canada Post Gateway Processing Centre  43.636966 -79.615819
# 77   Kingsview Village, Martin Grove Gardens, Richv...  43.688905 -79.554724
# 78                                           Agincourt  43.794200 -79.262029
# 79                                          Davisville  43.704324 -79.388790
# 80                      Harbord, University of Toronto  43.662696 -79.400049
# 81                                  Runnymede, Swansea  43.651571 -79.484450
# 82             Clarks Corners, Sullivan, Tam O'Shanter  43.781638 -79.304302
# 83                         Moore Park, Summerhill East  43.689574 -79.383160
# 84           Chinatown, Grange Park, Kensington Market  43.653206 -79.400049
# 85   Agincourt North, L'Amoreaux East, Milliken, St...  43.815252 -79.284577
# 86   Deer Park, Forest Hill SE, Rathnelly, South Hi...  43.686412 -79.400049
# 87   CN Tower, Bathurst Quay, Island airport, Harbo...  43.628947 -79.394420
# 88        Humber Bay Shores, Mimico South, New Toronto  43.605647 -79.501321
# 89   Albion Gardens, Beaumond Heights, Humbergate, ...  43.739416 -79.588437
# 90                       L'Amoreaux West, Steeles West  43.799525 -79.318389
# 91                                            Rosedale  43.679563 -79.377529
# 92                     Stn A PO Boxes 25 The Esplanade  43.646435 -79.374846
# 93                              Alderwood, Long Branch  43.602414 -79.543484
# 94                                           Northwest  43.706748 -79.594054
# 95                                         Upper Rouge  43.836125 -79.205636
# 96                         Cabbagetown, St. James Town  43.667967 -79.367675
# 97              First Canadian Place, Underground city  43.648429 -79.382280
# 98       The Kingsway, Montgomery Road, Old Mill North  43.653654 -79.506944
# 99                                Church and Wellesley  43.665860 -79.383160
# 100   Business reply mail Processing Centre969 Eastern  43.662744 -79.321558
# 101  Humber Bay, King's Mill Park, Kingsway Park So...  43.636258 -79.498509
# 102  Kingsway Park South West, Mimico NW, The Queen...  43.628841 -79.520999
#
#      PetScore
# 0           3
# 1           5
# 2          24
# 3           4
# 4          15
# 5           1
# 6           3
# 7           6
# 8           6
# 9          23
# 10          3
# 11          2
# 12          3
# 13          1
# 14          5
# 15         19
# 16          7
# 17          4
# 18          2
# 19         18
# 20         12
# 21          3
# 22          2
# 23          9
# 24         17
# 25         17
# 26          7
# 27          2
# 28          6
# 29          9
# ..        ...
# 73          9
# 74         18
# 75         15
# 76          4
# 77          2
# 78          6
# 79         19
# 80         14
# 81         10
# 82          3
# 83          4
# 84         22
# 85          2
# 86         10
# 87          7
# 88          4
# 89          1
# 90          1
# 91          7
# 92         18
# 93          2
# 94          1
# 95          1
# 96         13
# 97         18
# 98          8
# 99         20
# 100        11
# 101         3
# 102         8
#
# [103 rows x 6 columns]

# %% [markdown]
# Note that wild life control and other mistakes definitely exist in the answers. However in cases where the PetScore is already high they don't really make that much of a difference. After all most venues that are supposed to be pet-related are actually pet-related. Now we can order the table by PetScore.

# %%
df_loc_ordered = df_loc.sort_values('PetScore', ascending = False)
df_loc_ordered
# Out:
#     PostalCode           Borough  \
# 2          M5A  Downtown Toronto
# 37         M6J      West Toronto
# 9          M5B  Downtown Toronto
# 84         M5T  Downtown Toronto
# 48         M5L  Downtown Toronto
# 99         M4Y  Downtown Toronto
# 79         M4S   Central Toronto
# 30         M5H  Downtown Toronto
# 42         M5K  Downtown Toronto
# 15         M5C  Downtown Toronto
# 92         M5W  Downtown Toronto
# 19         M4E      East Toronto
# 74         M5R   Central Toronto
# 97         M5X  Downtown Toronto
# 24         M5G  Downtown Toronto
# 25         M6G  Downtown Toronto
# 67         M4P   Central Toronto
# 69         M6P      West Toronto
# 4          M7A      Queen's Park
# 75         M6R      West Toronto
# 80         M5S  Downtown Toronto
# 31         M6H      West Toronto
# 96         M4X  Downtown Toronto
# 54         M4M      East Toronto
# 47         M4L      East Toronto
# 20         M5E  Downtown Toronto
# 59         M2N        North York
# 100        M7Y      East Toronto
# 86         M4V   Central Toronto
# 41         M4K      East Toronto
# ..         ...               ...
# 101        M8Y         Etobicoke
# 39         M2K        North York
# 22         M1G       Scarborough
# 85         M1V       Scarborough
# 93         M8W         Etobicoke
# 18         M1E       Scarborough
# 11         M9B         Etobicoke
# 27         M2H        North York
# 60         M3N        North York
# 61         M4N   Central Toronto
# 40         M3K        North York
# 53         M3M        North York
# 49         M6L        North York
# 72         M2R        North York
# 77         M9R         Etobicoke
# 34         M3J        North York
# 32         M1J       Scarborough
# 44         M1L       Scarborough
# 45         M2L        North York
# 89         M9V         Etobicoke
# 90         M1W       Scarborough
# 13         M3C        North York
# 33         M2J        North York
# 46         M3L        North York
# 94         M9W         Etobicoke
# 95         M1X       Scarborough
# 56         M6M              York
# 5          M9A         Etobicoke
# 57         M9M        North York
# 58         M1N       Scarborough
#
#                                           Neighborhood   Latitude  Longitude  \
# 2                            Harbourfront, Regent Park  43.654260 -79.360636
# 37                            Little Portugal, Trinity  43.647927 -79.419750
# 9                             Ryerson, Garden District  43.657162 -79.378937
# 84           Chinatown, Grange Park, Kensington Market  43.653206 -79.400049
# 48                      Commerce Court, Victoria Hotel  43.648198 -79.379817
# 99                                Church and Wellesley  43.665860 -79.383160
# 79                                          Davisville  43.704324 -79.388790
# 30                            Adelaide, King, Richmond  43.650571 -79.384568
# 42            Design Exchange, Toronto Dominion Centre  43.647177 -79.381576
# 15                                      St. James Town  43.651494 -79.375418
# 92                     Stn A PO Boxes 25 The Esplanade  43.646435 -79.374846
# 19                                         The Beaches  43.676357 -79.293031
# 74                 The Annex, North Midtown, Yorkville  43.672710 -79.405678
# 97              First Canadian Place, Underground city  43.648429 -79.382280
# 24                                  Central Bay Street  43.657952 -79.387383
# 25                                            Christie  43.669542 -79.422564
# 67                                    Davisville North  43.712751 -79.390197
# 69                       High Park, The Junction South  43.661608 -79.464763
# 4                                         Queen's Park  43.662301 -79.389494
# 75                              Parkdale, Roncesvalles  43.648960 -79.456325
# 80                      Harbord, University of Toronto  43.662696 -79.400049
# 31                        Dovercourt Village, Dufferin  43.669005 -79.442259
# 96                         Cabbagetown, St. James Town  43.667967 -79.367675
# 54                                     Studio District  43.659526 -79.340923
# 47                      The Beaches West, India Bazaar  43.668999 -79.315572
# 20                                         Berczy Park  43.644771 -79.373306
# 59                                    Willowdale South  43.770120 -79.408493
# 100   Business reply mail Processing Centre969 Eastern  43.662744 -79.321558
# 86   Deer Park, Forest Hill SE, Rathnelly, South Hi...  43.686412 -79.400049
# 41                        The Danforth West, Riverdale  43.679557 -79.352188
# ..                                                 ...        ...        ...
# 101  Humber Bay, King's Mill Park, Kingsway Park So...  43.636258 -79.498509
# 39                                     Bayview Village  43.786947 -79.385975
# 22                                              Woburn  43.770992 -79.216917
# 85   Agincourt North, L'Amoreaux East, Milliken, St...  43.815252 -79.284577
# 93                              Alderwood, Long Branch  43.602414 -79.543484
# 18                   Guildwood, Morningside, West Hill  43.763573 -79.188711
# 11   Cloverdale, Islington, Martin Grove, Princess ...  43.650943 -79.554724
# 27                                   Hillcrest Village  43.803762 -79.363452
# 60                                 Downsview Northwest  43.761631 -79.520999
# 61                                       Lawrence Park  43.728020 -79.388790
# 40                         CFB Toronto, Downsview East  43.737473 -79.464763
# 53                                   Downsview Central  43.728496 -79.495697
# 49            Maple Leaf Park, North Park, Upwood Park  43.713756 -79.490074
# 72                                     Willowdale West  43.782736 -79.442259
# 77   Kingsview Village, Martin Grove Gardens, Richv...  43.688905 -79.554724
# 34                     Northwood Park, York University  43.767980 -79.487262
# 32                                 Scarborough Village  43.744734 -79.239476
# 44                     Clairlea, Golden Mile, Oakridge  43.711112 -79.284577
# 45                            Silver Hills, York Mills  43.757490 -79.374714
# 89   Albion Gardens, Beaumond Heights, Humbergate, ...  43.739416 -79.588437
# 90                       L'Amoreaux West, Steeles West  43.799525 -79.318389
# 13                    Flemingdon Park, Don Mills South  43.725900 -79.340923
# 33                        Fairview, Henry Farm, Oriole  43.778517 -79.346556
# 46                                      Downsview West  43.739015 -79.506944
# 94                                           Northwest  43.706748 -79.594054
# 95                                         Upper Rouge  43.836125 -79.205636
# 56      Del Ray, Keelesdale, Mount Dennis, Silverthorn  43.691116 -79.476013
# 5                                     Islington Avenue  43.667856 -79.532242
# 57                                    Emery, Humberlea  43.724766 -79.532242
# 58                         Birch Cliff, Cliffside West  43.692657 -79.264848
#
#      PetScore
# 2          24
# 37         23
# 9          23
# 84         22
# 48         22
# 99         20
# 79         19
# 30         19
# 42         19
# 15         19
# 92         18
# 19         18
# 74         18
# 97         18
# 24         17
# 25         17
# 67         16
# 69         16
# 4          15
# 75         15
# 80         14
# 31         13
# 96         13
# 54         12
# 47         12
# 20         12
# 59         12
# 100        11
# 86         10
# 41         10
# ..        ...
# 101         3
# 39          3
# 22          2
# 85          2
# 93          2
# 18          2
# 11          2
# 27          2
# 60          2
# 61          2
# 40          2
# 53          2
# 49          2
# 72          2
# 77          2
# 34          2
# 32          2
# 44          1
# 45          1
# 89          1
# 90          1
# 13          1
# 33          1
# 46          1
# 94          1
# 95          1
# 56          1
# 5           1
# 57          1
# 58          1
#
# [103 rows x 6 columns]

# %% [markdown]
# Now it is time to plot our results.

# %%
toronto_map = folium.Map(location=[LATITUDE, LONGITUDE], zoom_start=11)
for lat, lng, zipcode, ps in zip(df_loc.Latitude, df_loc.Longitude, df_loc.PostalCode, df_loc.PetScore):
    pcolor = ''
    if ps < 10:
        pcolor = 'red'
    elif ps < 15:
        pcolor = 'orange'
    elif ps < 20:
        pcolor = 'yellow'
    else:
        pcolor = 'green'
    folium.vector_layers.CircleMarker(
        [lat, lng],
        radius=5, # define how big you want the circle markers to be
        color=pcolor,
        fill=True,
        popup=zipcode + " " + str(ps),
        fill_color=pcolor,
        fill_opacity=0.6
    ).add_to(toronto_map)

# show map
toronto_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# It seems that M5A is the best postal area, followed by M6J, M5B, M5T and M5L. Now let's estimate the situation using boroughs.

# %%
df_b = df_loc[['Borough','PetScore']].groupby('Borough').mean().sort_values('PetScore', ascending = False)
df_b
# Out:
#                    PetScore
# Borough
# Downtown Toronto  16.666667
# Queen's Park      15.000000
# West Toronto      14.500000
# East Toronto      12.600000
# Central Toronto   10.555556
# East York          7.200000
# Mississauga        4.000000
# York               3.800000
# Etobicoke          3.333333
# North York         3.291667
# Scarborough        2.882353

# %% [markdown]
# In terms of boroughs Downtown Toronto is the best, followed by Queen's Park, West Toronto, East Toronto and Central Toronto. The rest have fairly low pet scores which may be a consequence of them not being very walkable. This isn't actually unfair to suburban areas because walkability is in fact desirable for pet-related locations. Central Toronto is a bit overrated due to M5W and East Toronto is slightly underrated due to M7Y but these shouldn't change the situation too much.

# %% [markdown]
# ## Conclusion

# %% [markdown]
# So the verdict is out: The best locaion for a new animal shelter is M5A, namely Harbourfront and Regent Park.
